# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from fasta import FASTQ

# %%
from Bio import SeqIO

# %%
PATH = "/Users/prupes/Downloads/cas13-master-TilingScreens-data/TilingScreens/data/CD46_library_final.fa"

# %%
FASTQ("~/Downloads/cas13-master-TilingScreens-data/TilingScreens/data/CD46_library_final.fa")
# Out:
# <FASTQ object on "/Users/prupes/Downloads/cas13-master-TilingScreens-data/TilingScreens/data/CD46_library_final.fa">

# %%
library("Biostrings")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-34cdafd3fc24> in <module>
# ----> 1 library("Biostrings")
#
# NameError: name 'library' is not defined

# %%
seqs = []
with open(PATH) as fasta_file:  # Will close handle cleanly
    identifiers = []
    lengths = []
    for seq_record in SeqIO.parse(fasta_file, 'fasta'):  # (generator)
        print(seq_record)
        seqs.append[]
        break
        identifiers.append(seq_record.id)
        lengths.append(len(seq_record.seq))
# Out:
# ID: crRNA0001:1-23
# Name: crRNA0001:1-23
# Description: crRNA0001:1-23
# Number of features: 0
# Seq('GGACAGGTGGGCGTGGCCCGAGC')

# %%
lengths
# Out:
# [23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
# ...
